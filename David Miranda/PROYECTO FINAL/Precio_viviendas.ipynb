# %% [markdown]
# La idea principal es predecir el valor de una vivienda
# El datasets encontrado fue en kaggle

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('HPI_master.csv')

# %%
data
# Out:
#             hpi_type     hpi_flavor  frequency                   level  \
# 0        traditional  purchase-only    monthly  USA or Census Division
# 1        traditional  purchase-only    monthly  USA or Census Division
# 2        traditional  purchase-only    monthly  USA or Census Division
# 3        traditional  purchase-only    monthly  USA or Census Division
# 4        traditional  purchase-only    monthly  USA or Census Division
# ...              ...            ...        ...                     ...
# 99320  developmental  purchase-only  quarterly             Puerto Rico
# 99321  developmental  purchase-only  quarterly             Puerto Rico
# 99322  developmental  purchase-only  quarterly             Puerto Rico
# 99323  developmental  purchase-only  quarterly             Puerto Rico
# 99324  developmental  purchase-only  quarterly             Puerto Rico
#
#                         place_name place_id    yr  period  index_nsa  index_sa
# 0      East North Central Division   DV_ENC  1991       1     100.00    100.00
# 1      East North Central Division   DV_ENC  1991       2     101.03    101.11
# 2      East North Central Division   DV_ENC  1991       3     101.40    101.08
# 3      East North Central Division   DV_ENC  1991       4     101.79    101.10
# 4      East North Central Division   DV_ENC  1991       5     102.44    101.50
# ...                            ...      ...   ...     ...        ...       ...
# 99320                  Puerto Rico       PR  2015       2     160.23    158.62
# 99321                  Puerto Rico       PR  2015       3     159.54    161.27
# 99322                  Puerto Rico       PR  2015       4     155.14    152.81
# 99323                  Puerto Rico       PR  2016       1     150.61    154.71
# 99324                  Puerto Rico       PR  2016       2     165.45    163.82
#
# [99325 rows x 10 columns]

# %%
data["level"].unique()
# Out:
# array(['USA or Census Division', 'MSA', 'State', 'Puerto Rico'],
#       dtype=object)
