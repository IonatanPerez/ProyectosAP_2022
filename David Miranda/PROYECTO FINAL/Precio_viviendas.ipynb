# %% [markdown]
# La idea principal es predecir el valor de una vivienda
# El datasets encontrado fue en kaggle

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# %%
data = pd.read_csv('HPI_master.csv')

# %%
data.dtypes
# Out:
# hpi_type       object
# hpi_flavor     object
# frequency      object
# level          object
# place_name     object
# place_id       object
# yr              int64
# period          int64
# index_nsa     float64
# index_sa      float64
# dtype: object
