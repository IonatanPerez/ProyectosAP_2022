# %% [markdown]
# primeras ideas
# + La probabilidad de que crezca un árbol.
# + Enfermedades crónicas.
# + Probabilidad de ventas de una tienda.
# +
# +

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_data = "LucasGraces/tp/datasets/"

# %%
data= pd.read_csv(path_data + "diamonds.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_51560\1592478098.py in <module>
# ----> 1 data= pd.read_csv(path_data + "diamonds.csv")
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# c:\Users\lucas\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/LucasGraces/tp/datasets/diamonds.csv'

# %% [markdown]
# Busque en kaggle y encontre este dataset
#
#
# https://www.kaggle.com/datasets/shivam2503/diamonds

# %%
data.head(3)
# Out:
#    Unnamed: 0  Calidad    Corte color  Diametro  Precio  Longitud  Ancho  \
# 0           1     0.23    Ideal     E      55.0     326      3.95   3.98
# 1           2     0.21  Premium     E      61.0     326      3.89   3.84
# 2           3     0.23     Good     E      65.0     327      4.05   4.07
#
#    Profundidad
# 0         2.43
# 1         2.31
# 2         2.31

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
data.shape
# Out:
# (53940, 11)

# %% [markdown]
# # Renombramiento de columnas

# %%
renombrar = {"cut": "Corte"}

# %%
data.rename(columns = renombrar, inplace=True)

# %%
renombrar1 = {"x": "Longitud"}

# %%
data.rename(columns = renombrar1, inplace=True)

# %%
renombrar2 = {"y": "Ancho"}

# %%
data.rename(columns = renombrar2, inplace=True)

# %%
renombrar3 = {"z": "Profundidad"}

# %%
data.rename(columns = renombrar3, inplace=True)

# %%
renombrar5 = {"price": "Precio"}

# %%
data.rename(columns = renombrar5, inplace=True)

# %%
renombrar6 = {"table": "Diametro"}

# %%
data.rename(columns = renombrar6, inplace=True)

# %%
renombrar7 = {"carat": "Calidad"}

# %%
data.rename(columns = renombrar7, inplace=True)

# %%
data
# Out:
#        Unnamed: 0  Calidad      Corte color clarity  depth  Diametro  Precio  \
# 0               1     0.23      Ideal     E     SI2   61.5      55.0     326
# 1               2     0.21    Premium     E     SI1   59.8      61.0     326
# 2               3     0.23       Good     E     VS1   56.9      65.0     327
# 3               4     0.29    Premium     I     VS2   62.4      58.0     334
# 4               5     0.31       Good     J     SI2   63.3      58.0     335
# ...           ...      ...        ...   ...     ...    ...       ...     ...
# 53935       53936     0.72      Ideal     D     SI1   60.8      57.0    2757
# 53936       53937     0.72       Good     D     SI1   63.1      55.0    2757
# 53937       53938     0.70  Very Good     D     SI1   62.8      60.0    2757
# 53938       53939     0.86    Premium     H     SI2   61.0      58.0    2757
# 53939       53940     0.75      Ideal     D     SI2   62.2      55.0    2757
#
#        Longitud  Ancho  Profundidad
# 0          3.95   3.98         2.43
# 1          3.89   3.84         2.31
# 2          4.05   4.07         2.31
# 3          4.20   4.23         2.63
# 4          4.34   4.35         2.75
# ...         ...    ...          ...
# 53935      5.75   5.76         3.50
# 53936      5.69   5.75         3.61
# 53937      5.66   5.68         3.56
# 53938      6.15   6.12         3.74
# 53939      5.83   5.87         3.64
#
# [53940 rows x 11 columns]

# %% [markdown]
# # Seleccion de columnas

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Calidad        0
# Corte          0
# color          0
# clarity        0
# depth          0
# Diametro       0
# Precio         0
# Longitud       0
# Ancho          0
# Profundidad    0
# dtype: int64

# %%
data= data.drop(columns = ['clarity'])

# %%
data = data.drop(columns = ['depth'])

# %%
data

# %% [markdown]
# # Paso todas las columnas a int

# %%
data.dtypes
# Out:
# Unnamed: 0       int64
# Calidad        float64
# Corte           object
# color           object
# Diametro       float64
# Precio           int64
# Longitud       float64
# Ancho          float64
# Profundidad    float64
# dtype: object

# %%
data['Corte'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
pd.get_dummies(data["Corte"])
