# %%
import pandas as pd

# %%
data = pd.read_csv("ar_properties.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11032/1178021609.py in <module>
# ----> 1 data = pd.read_csv("ar_properties.csv")
#
# c:\Users\Ionatan\anaconda3\envs\DH\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
